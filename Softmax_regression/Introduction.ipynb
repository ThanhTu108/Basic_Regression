# %% [markdown]
# # SoftMax

# %% [markdown]
# Logistic regression is a binary classification algorithm. It can be extended to multi-class classification using the SoftMax function.

# %% [markdown]
# SoftMax is many class classification algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Implementation

# %%
import numpy as np

# %%
#define function
def softmax_functionx(x):
    return (np.exp(x)) / np.sum(np.exp(x))
